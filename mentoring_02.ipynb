# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Certificate Programs

# %% [markdown]
# **Mentoring Session**

# %% [markdown]
# ## Imports

# %%
# !git clone https://github.com/tpq-classes/python_for_algo_trading_addon.git
import sys
sys.path.append('python_for_algo_trading_addon')

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Time to Maturity

# %%
T = 1.0

# %%
T = 0.5  # half a year as year fration

# %%
T = 1.5

# %%
pdate = '2020-06-04'
mdate = '2020-12-31'

# %%
p = pd.Timestamp(pdate)
m = pd.Timestamp(mdate)

# %%
p, m
# Out:
# (Timestamp('2020-06-04 00:00:00'), Timestamp('2020-12-31 00:00:00'))

# %%
m - p
# Out:
# Timedelta('210 days 00:00:00')

# %%
(m - p).days
# Out:
# 210

# %%
T = (m - p).days / 365
T
# Out:
# 0.5753424657534246

# %% [markdown]
# ## Oanda Data

# %%
import tpqoa
import cufflinks

# %%
api = tpqoa.tpqoa('../../../data/pyalgo.cfg')

# %%
api.get_instruments()[:5]
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD')]

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price, localize=True) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
# ...
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask), 'B' (bid) or 'M' (middle)
#
#     Returns
# ...
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
instrument = 'EUR_USD'
start = '2020-05-01'
end = '2020-05-31'
granularity = 'M10'
price = 'M'

# %%
# %time data = api.get_history(instrument, start, end, granularity, price)
# Out:
# CPU times: user 368 ms, sys: 8.48 ms, total: 377 ms
# Wall time: 13.6 s

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3003 entries, 2020-05-01 00:00:00 to 2020-05-29 20:50:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   o         3003 non-null   float64
#  1   h         3003 non-null   float64
#  2   l         3003 non-null   float64
#  3   c         3003 non-null   float64
#  4   volume    3003 non-null   int64
#  5   complete  3003 non-null   bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 143.7 KB

# %%
data.tail()
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-05-29 20:10:00  1.11004  1.11028  1.10994  1.11026     161      True
# 2020-05-29 20:20:00  1.11028  1.11032  1.10980  1.10985     200      True
# 2020-05-29 20:30:00  1.10986  1.11037  1.10984  1.11018     213      True
# 2020-05-29 20:40:00  1.11020  1.11079  1.11016  1.11050     259      True
# 2020-05-29 20:50:00  1.11048  1.11088  1.11025  1.11053     311      True

# %%
data['c'].iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /anaconda/lib/python3.8/site-packages/cufflinks/plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-1f71e036d475> in <module>
# ----> 1 data['c'].iplot()
#
# ...

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
